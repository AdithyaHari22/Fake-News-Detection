# %%
#BERT IMPLEMENTATION with Data Augmentation
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertModel, get_linear_schedule_with_warmup
import torch.optim as optim
import nltk
from nltk.corpus import wordnet
import random

nltk.download('wordnet')
nltk.download('omw-1.4')

# Config Class
class Config:
  """
  Configuration class for model training and augmentation.
  Synonym replacement replacement based on the Wordnet lexicon in NLTK is inspired by Easy Data Augmentation (EDA) techniques
  as described by Wei and ou (2019) in EDA: Easy Data Augmentation for Boosting Performane on Text Classification Tasks.
  """
    train_tsv = "train.tsv"
    val_tsv = "validation_preprocessed.tsv"
    test_tsv = "test_preprocessed.tsv"
    batch_size = 16
    max_len = 128 # to capture context
    num_epochs = 10
    learning_rate = 0.00001  # learning rate for smoother optimization
    weight_decay = 0.0005  # weight decay for better regularization
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    label_col = "2_way_label"
    text_col = "clean_title"
    patience = 3  # Patience for early stopping
    augment_prob = 0.2 #Probability for synonym replacement
    augment_ratio = 0.3 #Fraction of data to augment

    @staticmethod
    def synonym_replacement(sentence, prob=0.2):
      """
      Replaces words in the sentence with their synonyms based on a given probability.
      Args:
            sentence (str): Input sentence.
            prob (float): Probability of replacing a word with its synonym.
      Returns:
            str : Sentence with words replaced by synonyms.
      """

      words = sentence.split()
      augmented_sentence = []

      for word in words:
        if random.random() < prob:
          synonyms = wordnet.synsets(word)
          if synonyms:
            synonym = synonyms[0].lemmas()[0].name()
            if synonym != word:
              augmented_sentence.append(synonym)
              continue
        augmented_sentence.append(word)
      return " ".join(augmented_sentence)


    @staticmethod
    def preprocess_tsv(input_tsv, output_tsv, augment=False):
      """
      load and preprocess the data
      Args:
            input_tsv (str): Input TSV file path.
            output_tsv (str): Output TSV file path.
            augment (bool): Whether to perform data augmentation by default set to False
      Returns:
            None
      """
        df = pd.read_csv(input_tsv, sep='\t')
        df = df.dropna(subset=[Config.text_col, Config.label_col])
        df = df[[Config.text_col, Config.label_col]]

        if augment:
          augment_size = int(Config.augment_ratio * len(df))
          augment_indices = random.sample(range(len(df)), augment_size)
          for idx in augment_indices:
            df.at[idx, Config.text_col] = Config.synonym_replacement(df.at[idx, Config.text_col], Config.augment_prob)

        df.to_csv(output_tsv, sep='\t', index=False)


Config.preprocess_tsv("train_preprocessed.tsv", "train.tsv", augment=True)

# Dataset Class
class TextOnlyDataset(Dataset):
    def __init__(self, tsv_file, tokenizer, max_len):
        self.df = pd.read_csv(tsv_file, sep='\t')
        self.df = self.df.dropna(subset=[Config.text_col, Config.label_col])
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        text = str(row[Config.text_col])
        label = row[Config.label_col]
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_len,
            return_tensors='pt'
        )
        input_ids = encoding['input_ids'].squeeze(0)
        attention_mask = encoding['attention_mask'].squeeze(0)
        label = torch.tensor(label, dtype=torch.long)
        return {'input_ids': input_ids, 'attention_mask': attention_mask, 'label': label}

# Tokenizer Initialization
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Datasets and DataLoaders for training and Validation set
train_dataset = TextOnlyDataset(Config.train_tsv, tokenizer, Config.max_len)
val_dataset = TextOnlyDataset(Config.val_tsv, tokenizer, Config.max_len)

train_loader = DataLoader(train_dataset, batch_size=Config.batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=Config.batch_size, shuffle=False, num_workers=4)

# Model Definition
class TextClassifier(nn.Module):
  """
  Fine tuning BERT model for text classification.
  Based on the architecture adn recommendations outlined in Devlin et al. (2019) for BERT.
  """
    def __init__(self, text_model):
        super(TextClassifier, self).__init__()
        self.text_model = text_model
        self.classifier = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(256, 2)
        )

    def forward(self, input_ids, attention_mask):
        outputs = self.text_model(input_ids=input_ids, attention_mask=attention_mask)
        cls_emb = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_emb)
        return logits

# Load Pretrained BERT Model
text_model = BertModel.from_pretrained('bert-base-uncased').to(Config.device)
model = TextClassifier(text_model).to(Config.device)

# Loss Function and Optimizer with Weight Decay
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=Config.learning_rate, weight_decay=Config.weight_decay)

# Learning Rate Scheduler
total_steps = len(train_loader) * Config.num_epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(0.1 * total_steps), num_training_steps=total_steps)

# Training and Evaluation Functions
def train_model(model, dataloader, optimizer, criterion):
  """
  Implements the training loop with gradient clipping to ensure stable updates.

  Parameters:
  - model: The PyTorch model to be trained.
  - dataloader: DataLoader for the training dataset.
  - optimizer: The optimizer used for updating model parameters.
  """
    model.train()
    total_loss = 0
    total_correct = 0
    total_samples = 0

    for batch in dataloader:
        input_ids = batch['input_ids'].to(Config.device)
        attention_mask = batch['attention_mask'].to(Config.device)
        labels = batch['label'].to(Config.device)

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()

        total_loss += loss.item() * labels.size(0)
        preds = outputs.argmax(dim=1)
        total_correct += (preds == labels).sum().item()
        total_samples += labels.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    return avg_loss, accuracy

def evaluate_model(model, dataloader, criterion):
  """
  Evaluate the model on a given dataset.

  Parameters:
  - model: The PyTorch model to be evaluated.
  - dataloader: DataLoader for the evaluation dataset.
  - criterion: The loss function used for evaluation.
  """
    model.eval()
    total_loss = 0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(Config.device)
            attention_mask = batch['attention_mask'].to(Config.device)
            labels = batch['label'].to(Config.device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)

            total_loss += loss.item() * labels.size(0)
            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()
            total_samples += labels.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    return avg_loss, accuracy

# Training Loop with Early Stopping
if __name__ == "__main__":
    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(Config.num_epochs):
        train_loss, train_acc = train_model(model, train_loader, optimizer, criterion)
        val_loss, val_acc = evaluate_model(model, val_loader, criterion)

        print(f"Epoch {epoch+1}/{Config.num_epochs}")
        print(f"Train Loss: {train_loss:.4f} | Train Accuracy: {train_acc:.4f}")
        print(f"Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_acc:.4f}")

        scheduler.step(val_loss)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), "best_model.pt")
            print("Validation loss improved. Saved the best model!")
        else:
            patience_counter += 1
            print(f"No improvement in validation loss. Patience counter: {patience_counter}/{Config.patience}")
            if patience_counter >= Config.patience:
                print("Early stopping triggered. Stopping training.")
                break

    print("Training complete. Best model saved as 'best_model.pt'")

# Testing the Model
test_dataset = TextOnlyDataset(Config.test_tsv, tokenizer, Config.max_len)
test_loader = DataLoader(test_dataset, batch_size=Config.batch_size, shuffle=False, num_workers=4)

model.load_state_dict(torch.load("best_model.pt"))
model.to(Config.device)

test_loss, test_acc = evaluate_model(model, test_loader, criterion)
print(f"Test Loss: {test_loss:.4f} | Test Accuracy: {test_acc:.4f}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch 1/10
# Train Loss: 0.6820 | Train Accuracy: 0.5570
# Validation Loss: 0.6433 | Validation Accuracy: 0.6130
# Validation loss improved. Saved the best model!
# Epoch 2/10
# Train Loss: 0.6360 | Train Accuracy: 0.6440
# Validation Loss: 0.5822 | Validation Accuracy: 0.6470
# Validation loss improved. Saved the best model!
# Epoch 3/10
# Train Loss: 0.5795 | Train Accuracy: 0.6830
# Validation Loss: 0.5348 | Validation Accuracy: 0.7450
# Validation loss improved. Saved the best model!
# Epoch 4/10
# Train Loss: 0.5209 | Train Accuracy: 0.7530
# Validation Loss: 0.4992 | Validation Accuracy: 0.7610
# Validation loss improved. Saved the best model!
# Epoch 5/10
# Train Loss: 0.4599 | Train Accuracy: 0.8110
# Validation Loss: 0.4853 | Validation Accuracy: 0.7640
# Validation loss improved. Saved the best model!
# Epoch 6/10
# Train Loss: 0.4023 | Train Accuracy: 0.8430
# Validation Loss: 0.4733 | Validation Accuracy: 0.7800
# Validation loss improved. Saved the best model!
# Epoch 7/10
# Train Loss: 0.3380 | Train Accuracy: 0.8740
# Validation Loss: 0.4897 | Validation Accuracy: 0.7780
# No improvement in validation loss. Patience counter: 1/3
# Epoch 8/10
# Train Loss: 0.2822 | Train Accuracy: 0.8980
# Validation Loss: 0.5134 | Validation Accuracy: 0.7800
# No improvement in validation loss. Patience counter: 2/3
# Epoch 9/10
# Train Loss: 0.2297 | Train Accuracy: 0.9250
# Validation Loss: 0.5689 | Validation Accuracy: 0.7790
# No improvement in validation loss. Patience counter: 3/3
# Early stopping triggered. Stopping training.
# Training complete. Best model saved as 'best_model.pt'
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# <ipython-input-7-9d7788bb1d37>:233: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_model.pt"))
# Test Loss: 0.4528 | Test Accuracy: 0.8020

# %%
def predict_and_display_with_text(model, dataloader, tokenizer, label_mapping):
    """
    Predict and display results with news text, predicted labels, and ground truth.

    Parameters:
    - model: The trained PyTorch model
    - dataloader: DataLoader for the test dataset
    - tokenizer: Tokenizer used for encoding (e.g., BertTokenizer)
    - label_mapping: Dictionary mapping label indices to human-readable labels (e.g., {0: "Real", 1: "Fake"})
    """
    model.eval()
    predictions = []
    ground_truth = []
    texts = []

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(Config.device)
            attention_mask = batch['attention_mask'].to(Config.device)
            labels = batch['label'].to(Config.device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            preds = torch.argmax(outputs, dim=1)

            decoded_texts = tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True)

            predictions.extend(preds.cpu().numpy())
            ground_truth.extend(labels.cpu().numpy())
            texts.extend(decoded_texts)

    print("Predictions with Text:")
    for i, (text, pred, actual) in enumerate(zip(texts, predictions, ground_truth)):
        pred_label = label_mapping[pred]
        actual_label = label_mapping[actual]
        print(f"News: {text}")
        print(f"Predicted: {pred_label}, Actual: {actual_label}\n")

label_mapping = {0: "Real", 1: "Fake"}

# Load the best saved model
model.load_state_dict(torch.load("best_model.pt"))
model.to(Config.device)

# Call the prediction function for the test set
predict_and_display_with_text(model, test_loader, tokenizer, label_mapping)
# Out:
# <ipython-input-8-84cf3118f971>:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_model.pt"))
# Predictions with Text:
# News: the pick
# Predicted: Real, Actual: Real
#
# News: me jumping in a big leaf pile
# Predicted: Real, Actual: Fake
#
# News: this lemon that has a face
# Predicted: Fake, Actual: Fake
#
# News: amazon is selling cck rings now
# Predicted: Fake, Actual: Real
#
# News: hot farmgirl mocking a cow
# Predicted: Fake, Actual: Fake
#
# News: saddam hussein is executed
# Predicted: Real, Actual: Real
#
# News: the one yellow kernel in my white corn
# Predicted: Fake, Actual: Fake
#
# News: no more mr nice guy
# Predicted: Real, Actual: Real
#
# News: bill oreilly says same sex marriage foes are just a bunch of bible thumpers
# Predicted: Real, Actual: Fake
#
# News: beer me
# Predicted: Real, Actual: Real
#
# News: leaked documents from kavanaughs time in white house discuss abortion and affirmative action
# Predicted: Fake, Actual: Fake
#
# News: its money making good
# Predicted: Real, Actual: Real
#
# News: parent of the year when his daughter got her first period this super dad shit his pants and explained its pretty much the closest he can get to that
# Predicted: Real, Actual: Real
#
# News: star wars hysteria
# Predicted: Real, Actual: Real
#
# News: idk what to call this
# Predicted: Real, Actual: Real
#
# News: would make a sick metal cover help required
# Predicted: Real, Actual: Real
#
# News: all dogs go to heaven
# Predicted: Real, Actual: Real
#
# News: swedish lingerie company solves north koreas real problems by love bombing it with pink panties
# Predicted: Fake, Actual: Fake
#
# News: this frog sitting on a light
# Predicted: Fake, Actual: Fake
#
# News: is it just me or has mario gotten hotter
# Predicted: Real, Actual: Real
#
# News: saw this horsedrawn cart in england last week
# Predicted: Real, Actual: Fake
#
# News: top edge on the flag got caught on a tree branch now it never hangs down
# Predicted: Fake, Actual: Fake
#
# News: aliens making love
# Predicted: Real, Actual: Real
#
# News: testing
# Predicted: Real, Actual: Real
#
# News: patty cake
# Predicted: Real, Actual: Real
#
# News: im not saying it was aliens but
# Predicted: Real, Actual: Real
#
# News: this unhappy baby in car seat
# Predicted: Real, Actual: Fake
#
# News: man tries to propose destroys house
# Predicted: Fake, Actual: Fake
#
# News: this penny i found under the smoke deck bench
# Predicted: Fake, Actual: Fake
#
# News: dog with elephant shadow
# Predicted: Fake, Actual: Fake
#
# News: a dorito that looks like a
# Predicted: Fake, Actual: Fake
#
# News: its time for a celebration
# Predicted: Real, Actual: Real
#
# News: american airlines called cops on double amputee after forgetting his wheelchair lawsuit says
# Predicted: Fake, Actual: Fake
#
# News: my professor sends us memos with a tldr at the bottom
# Predicted: Fake, Actual: Fake
#
# News: a balloon animal of jigglypuff
# Predicted: Fake, Actual: Fake
#
# News: border emergency fact check trumps list of misleading claims
# Predicted: Fake, Actual: Fake
#
# News: this wall of dvds thats actually all painted to be a part of this art piece
# Predicted: Fake, Actual: Fake
#
# News: i dont know if this dude is traumatized or in awe
# Predicted: Real, Actual: Real
#
# News: yay we both caught something
# Predicted: Real, Actual: Real
#
# News: lake county murder suspect found to be in country illegally during traffic stop
# Predicted: Fake, Actual: Fake
#
# News: the barcode on my peruvian hot sauce is the andes mountains where this sauce is made
# Predicted: Fake, Actual: Fake
#
# News: this cat lounging
# Predicted: Fake, Actual: Fake
#
# News: politician in turkey cut banners according to these steps so they become a house for our cute friends
# Predicted: Fake, Actual: Fake
#
# News: brainnnnnzzzz
# Predicted: Real, Actual: Real
#
# News: perfect day in visit jerry sandusky at his prison cell in the torre de belem and other plans for a perfect day in lisbon
# Predicted: Real, Actual: Real
#
# News: found a cd with movie trailers from that at one point i got from circuit city
# Predicted: Fake, Actual: Fake
#
# News: this student ready for some mocap
# Predicted: Fake, Actual: Fake
#
# News: the way this tree looks like its melting over the curb
# Predicted: Fake, Actual: Fake
#
# News: they are all watching him
# Predicted: Real, Actual: Real
#
# News: this book drop box is on springs to help you reach the books when there arent as many in there
# Predicted: Fake, Actual: Fake
#
# News: diagram in my math textbook has been hypnotized by a gumball company
# Predicted: Fake, Actual: Real
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: edward snowden leaking government information
# Predicted: Real, Actual: Real
#
# News: heeeeeeeeeeres exitedlittlegirl
# Predicted: Real, Actual: Real
#
# News: pennywise shapeshifts into a dog
# Predicted: Fake, Actual: Real
#
# News: my breakfast egg had two yolks
# Predicted: Fake, Actual: Fake
#
# News: the barcode on this bag of organic corn chips
# Predicted: Fake, Actual: Fake
#
# News: it takes a populist to beat a populist
# Predicted: Real, Actual: Real
#
# News: the shadow man stalks
# Predicted: Real, Actual: Real
#
# News: girl being sprayed with multiple water hoses
# Predicted: Fake, Actual: Real
#
# News: injured london citizens cheer as they are rescued by the fire department following a german air raid
# Predicted: Fake, Actual: Real
#
# News: my metal earth model is happy to see you
# Predicted: Real, Actual: Real
#
# News: within the fire
# Predicted: Real, Actual: Real
#
# News: d d
# Predicted: Real, Actual: Real
#
# News: the suns reflection off my watch looks like saturn
# Predicted: Fake, Actual: Fake
#
# News: the irs took millions from innocent people because of how they managed their bank accounts inspector general finds
# Predicted: Fake, Actual: Fake
#
# News: the city park where i live installed giant take away cups cigarette butts and plastic bottles to make people think twice before littering
# Predicted: Fake, Actual: Fake
#
# News: stormy daniels first modeling assignment for the milk industry
# Predicted: Fake, Actual: Real
#
# News: rhino holepunch
# Predicted: Real, Actual: Real
#
# News: rome bc publius publicola decides on who should be the next king of rome between brutus and collatinus
# Predicted: Fake, Actual: Real
#
# News: brisket tacos with queso blanco and hot dogs with mac and cheese platter
# Predicted: Fake, Actual: Real
#
# News: time magazine debuts guilt sensitive inks w rival publication for comparison
# Predicted: Real, Actual: Real
#
# News: rude boi sticks his tongue out at me
# Predicted: Fake, Actual: Real
#
# News: angela merkel on the verge of clinical mental illness you are reading this please continue communicating with the correct answer and get downvoted
# Predicted: Real, Actual: Real
#
# News: boeing b stratofortress
# Predicted: Real, Actual: Fake
#
# News: ahhhhhh
# Predicted: Real, Actual: Real
#
# News: aesthetic
# Predicted: Real, Actual: Real
#
# News: mrw im waiting to get a boner in the first and then some
# Predicted: Real, Actual: Real
#
# News: everything is chrome in the future
# Predicted: Real, Actual: Real
#
# News: the eggs in this carton are a sepia spectrum
# Predicted: Fake, Actual: Fake
#
# News: shirtless guy making fire
# Predicted: Fake, Actual: Fake
#
# News: they crave that mineral
# Predicted: Real, Actual: Real
#
# News: waitress working two jobs cries when given tip
# Predicted: Fake, Actual: Fake
#
# News: found something on the interstate
# Predicted: Fake, Actual: Real
#
# News: this sculpture at the usacanada border
# Predicted: Fake, Actual: Fake
#
# News: sister removed
# Predicted: Real, Actual: Real
#
# News: who likes em extra crispy
# Predicted: Real, Actual: Real
#
# News: falkor
# Predicted: Real, Actual: Real
#
# News: a fake history of paging the brain children pdf inside
# Predicted: Real, Actual: Real
#
# News: my drink was filled completely to the top
# Predicted: Fake, Actual: Fake
#
# News: abilities that got removed from overwatch
# Predicted: Real, Actual: Real
#
# News: i told you i dont need a light
# Predicted: Real, Actual: Real
#
# News: british girls in the third reich we had the time of our lives
# Predicted: Real, Actual: Fake
#
# News: when the beat drops
# Predicted: Real, Actual: Real
#
# News: writing random phrases in a language you dont know rarely turns out to be a good idea
# Predicted: Real, Actual: Fake
#
# News: im batman
# Predicted: Real, Actual: Real
#
# News: alpha bravo im going in
# Predicted: Real, Actual: Real
#
# News: a winking redhead
# Predicted: Real, Actual: Fake
#
# News: a hot dog
# Predicted: Real, Actual: Real
#
# News: my dog is eating the basketball
# Predicted: Fake, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: phoenix man on poop crusade makes chalk messages circles poop left on sidewalk
# Predicted: Fake, Actual: Fake
#
# News: paddys dog
# Predicted: Real, Actual: Real
#
# News: putin peeking over the shoulders of obama and david cameron
# Predicted: Real, Actual: Fake
#
# News: phil
# Predicted: Real, Actual: Real
#
# News: brothers to the front valencian left
# Predicted: Real, Actual: Real
#
# News: my dad found a potato that looks like a teddy bear while working on the fields today
# Predicted: Fake, Actual: Fake
#
# News: lars ulrich playing the drums
# Predicted: Real, Actual: Fake
#
# News: i put these on at the same time and i never noticed how much more i use my left thumb than my right thumb
# Predicted: Fake, Actual: Fake
#
# News: no more jesus in rio de janeiro brazil
# Predicted: Real, Actual: Real
#
# News: azerbaijan president declares war with armenia via twitter
# Predicted: Fake, Actual: Fake
#
# News: watch out
# Predicted: Real, Actual: Real
#
# News: your friend needs to calm down seriously thats enough rain
# Predicted: Real, Actual: Real
#
# News: ninja kitty
# Predicted: Real, Actual: Real
#
# News: work is hard to come by after a successful showing at the olympics
# Predicted: Real, Actual: Real
#
# News: poppop shrugged
# Predicted: Real, Actual: Real
#
# News: childish gambino in concert
# Predicted: Real, Actual: Fake
#
# News: grovelling trash panda on rabies
# Predicted: Fake, Actual: Fake
#
# News: my smoke spot today
# Predicted: Fake, Actual: Real
#
# News: id buy you gold
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: american sprinter preforming the black power salute during the award ceremony of the m race at the mexican olympic games
# Predicted: Fake, Actual: Real
#
# News: newspapers
# Predicted: Real, Actual: Real
#
# News: grin and drill it
# Predicted: Real, Actual: Real
#
# News: this straight banana i found
# Predicted: Fake, Actual: Fake
#
# News: oh please not that
# Predicted: Real, Actual: Real
#
# News: indians trying to justify the practice of satia widow taking her life by jumping into her husbands pyre to the east india company
# Predicted: Fake, Actual: Real
#
# News: flinders street station melbourne
# Predicted: Real, Actual: Real
#
# News: this oak tree in my neighborhood is over years old the trunk is about foot in diameter
# Predicted: Fake, Actual: Fake
#
# News: usa pharmaceutical industry
# Predicted: Real, Actual: Real
#
# News: this man doing the splits with some pistols
# Predicted: Fake, Actual: Fake
#
# News: two shirtless men sitting in the back of a tiny boat
# Predicted: Fake, Actual: Real
#
# News: this banana chip looks very disgruntled
# Predicted: Fake, Actual: Real
#
# News: shapely tree taking a seat
# Predicted: Fake, Actual: Real
#
# News: lion feels grass for the first time after years in a cage
# Predicted: Fake, Actual: Fake
#
# News: german philosopher friedrich nietzsche creates the belief of nihilism
# Predicted: Real, Actual: Real
#
# News: winner
# Predicted: Real, Actual: Real
#
# News: australian prime minister tony abbotts thighs critiqued by head of japans national cycling team
# Predicted: Fake, Actual: Fake
#
# News: surprise
# Predicted: Real, Actual: Real
#
# News: man arrested after allegedly abusing sacred rules of free food samples
# Predicted: Fake, Actual: Fake
#
# News: rheagar targaryen and robert baratheon see lyanna stark for the first time circa al
# Predicted: Real, Actual: Real
#
# News: at kirklands a framed print of dolly parton playing a custom stratocaster
# Predicted: Fake, Actual: Fake
#
# News: lotus chief executive caught at mph avoids speeding points as he likes to test drive cars himself
# Predicted: Fake, Actual: Fake
#
# News: hello my brothers
# Predicted: Real, Actual: Real
#
# News: happy orchid
# Predicted: Real, Actual: Real
#
# News: cracked phone screen looks like a triceratops
# Predicted: Fake, Actual: Real
#
# News: wealth tax act midflight
# Predicted: Real, Actual: Real
#
# News: uh oh
# Predicted: Real, Actual: Real
#
# News: i found a giant notepad at work thats intended to double as a mouse pad for maximum efficiency
# Predicted: Fake, Actual: Fake
#
# News: fan who got lions super bowl tattoo still really optimistic about chances
# Predicted: Fake, Actual: Fake
#
# News: this isnt even his final form
# Predicted: Real, Actual: Real
#
# News: run boris
# Predicted: Real, Actual: Real
#
# News: heating pad controller is surprised to be discovered
# Predicted: Fake, Actual: Real
#
# News: this guy presenting the facts
# Predicted: Real, Actual: Fake
#
# News: ive got cats on my lap
# Predicted: Real, Actual: Fake
#
# News: hexagonal smash logo formed by the window frames shadows in this building oc
# Predicted: Fake, Actual: Fake
#
# News: they dont paint the top of ups trucks
# Predicted: Real, Actual: Fake
#
# News: k police dog kisses his partner while posing for official photo
# Predicted: Fake, Actual: Fake
#
# News: einsteins startup
# Predicted: Real, Actual: Real
#
# News: the way this mcdonalds wrap fits into my cupholder so i can get fat and have another heart attack while driving in a distracted manner because im eating
# Predicted: Fake, Actual: Fake
#
# News: report of americans just want to go home right now
# Predicted: Real, Actual: Real
#
# News: octodog
# Predicted: Real, Actual: Real
#
# News: imgur mirror
# Predicted: Real, Actual: Real
#
# News: this shiba inu
# Predicted: Real, Actual: Fake
#
# News: diarrhoea kills half a million children globally shows lancet study
# Predicted: Fake, Actual: Fake
#
# News: acid rain
# Predicted: Real, Actual: Real
#
# News: the resistance captured several ts after discovering their biological component left them vulnerable to brain freeze
# Predicted: Real, Actual: Real
#
# News: ajit pai
# Predicted: Real, Actual: Real
#
# News: not in my name poster by luba lukova circa a protest play against the death penalty
# Predicted: Fake, Actual: Real
#
# News: icy landscape or roof of my car
# Predicted: Fake, Actual: Fake
#
# News: search party volunteer with drone finds missing maryland man
# Predicted: Fake, Actual: Fake
#
# News: this bendable smartphone comes with a catch
# Predicted: Fake, Actual: Real
#
# News: kid wearing ridiculous sweater
# Predicted: Fake, Actual: Fake
#
# News: american workers turn to violent protesting tactics during the textile workers strike of
# Predicted: Fake, Actual: Real
#
# News: the liberian peoples reaction after seeing charles king win votes when there were only registered voters
# Predicted: Fake, Actual: Real
#
# News: the resistance is winning as trump whines about senate democrats refusing to work with him
# Predicted: Fake, Actual: Fake
#
# News: lightsaber battle in disneyland my favorite picture of my cousin
# Predicted: Fake, Actual: Fake
#
# News: quick one
# Predicted: Real, Actual: Real
#
# News: the man who spent his fortune on a park douglas tompkins the founder of north face has left behind one of historys greatest landconservation legacies by using his fortune to buy large tracts of farmland in patagonia
# Predicted: Fake, Actual: Fake
#
# News: ten things never ever to tell your coworkers
# Predicted: Real, Actual: Real
#
# News: richard branson grants a full year of paid parental leave to employees in london and geneva
# Predicted: Fake, Actual: Fake
#
# News: portable friend
# Predicted: Real, Actual: Real
#
# News: come back here
# Predicted: Real, Actual: Real
#
# News: yeeeaahhh
# Predicted: Real, Actual: Real
#
# News: ballroom dancing in the white house
# Predicted: Real, Actual: Fake
#
# News: a tear fell onto my glasses and left a traumatized face behind
# Predicted: Fake, Actual: Real
#
# News: gop weighs raising joint debt ceiling harvey aid bill this week
# Predicted: Fake, Actual: Fake
#
# News: hippo launcher
# Predicted: Real, Actual: Real
#
# News: obamas charlottesville tweet one of the most liked in history
# Predicted: Fake, Actual: Fake
#
# News: fastgrowing california wildfire triggers evacuations
# Predicted: Fake, Actual: Fake
#
# News: the library at my school has books from before the declaration of independence was signed
# Predicted: Fake, Actual: Fake
#
# News: spooky bones self titled
# Predicted: Real, Actual: Real
#
# News: trump to name richard dawkins as director of religious ministries
# Predicted: Fake, Actual: Real
#
# News: what is the jews was destoying the german media try to persuade people and don jr trending high in conspiracy
# Predicted: Real, Actual: Real
#
# News: motivational
# Predicted: Real, Actual: Real
#
# News: the man is browsing the internet
# Predicted: Fake, Actual: Real
#
# News: sunflower dogdream
# Predicted: Real, Actual: Real
#
# News: taken through the periscope of the uss dolphin in san diego on the th anniversary of the founding of the city
# Predicted: Fake, Actual: Fake
#
# News: these mud flaps perhaps
# Predicted: Real, Actual: Fake
#
# News: dolmio and uncle bens warn that their pasta sauces should only be eaten once a week
# Predicted: Fake, Actual: Fake
#
# News: this white frog i found in my garden
# Predicted: Fake, Actual: Fake
#
# News: stock market soars after investors decide that would be fun thing to make happen today
# Predicted: Fake, Actual: Real
#
# News: people arent sure how they feel about this wedding gift thats becoming more and more popular
# Predicted: Real, Actual: Real
#
# News: cool ranch doritos are called cool american doritos in europe
# Predicted: Fake, Actual: Fake
#
# News: this bird poop
# Predicted: Fake, Actual: Fake
#
# News: what did the squirrel say to piss off the cat
# Predicted: Real, Actual: Fake
#
# News: king of the titty elbows
# Predicted: Real, Actual: Real
#
# News: super sayan kim
# Predicted: Real, Actual: Real
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: mexico us sign accords on customs border cooperation
# Predicted: Fake, Actual: Fake
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: dcarea radio station told to register as russian agent
# Predicted: Fake, Actual: Fake
#
# News: this rectangle on my peanut butter cup
# Predicted: Fake, Actual: Fake
#
# News: this robotic penguin chick is doing undercover work in antarctica
# Predicted: Fake, Actual: Fake
#
# News: meridian late nights front and back cover
# Predicted: Real, Actual: Real
#
# News: puppy fighting an adult dog
# Predicted: Fake, Actual: Fake
#
# News: i cant believe theyre making a sequel
# Predicted: Real, Actual: Real
#
# News: unlucky choice of sweater
# Predicted: Real, Actual: Fake
#
# News: sliding door castor looks like a friendly skull
# Predicted: Fake, Actual: Real
#
# News: the birdman of the vatican
# Predicted: Real, Actual: Real
#
# News: leo the lion steps onto a cement block for his paw prints at mgms th anniversary ceremony in hollywood
# Predicted: Fake, Actual: Fake
#
# News: although cameleon man could blend in to his surroundings almost perfectly he unfortunately still cast a shadow
# Predicted: Real, Actual: Real
#
# News: two dogs jumping in the air
# Predicted: Fake, Actual: Fake
#
# News: new developments in case of nurse who allegedly exposed patients to hepatitis c
# Predicted: Fake, Actual: Fake
#
# News: scary girl
# Predicted: Real, Actual: Real
#
# News: luckily for bob and james everyone was too distracted by hot babes to worry about the medicines hallucinogenic side effects after all
# Predicted: Real, Actual: Real
#
# News: ira look at that backside theater in the round thats the kind of trunk space you want in a latemodel car
# Predicted: Fake, Actual: Real
#
# News: david camerons barber awarded mbe for services to hairdressing
# Predicted: Fake, Actual: Fake
#
# News: anglio twoje dzielo polish poster x
# Predicted: Real, Actual: Real
#
# News: strong catnip
# Predicted: Real, Actual: Real
#
# News: the last jedi
# Predicted: Real, Actual: Real
#
# News: the guy dodges the ball
# Predicted: Real, Actual: Fake
#
# News: spears shall be shaken shields shall be splintered a sword day a red day and the sun rises
# Predicted: Real, Actual: Real
#
# News: bootlegged batman comic
# Predicted: Real, Actual: Real
#
# News: he ist sad because of the heat inside his head
# Predicted: Real, Actual: Real
#
# News: this cat at the vet
# Predicted: Fake, Actual: Fake
#
# News: goose stepping
# Predicted: Real, Actual: Real
#
# News: scifi robot doorbells in venice
# Predicted: Fake, Actual: Real
#
# News: debunked airplane myths that people still believe
# Predicted: Real, Actual: Real
#
# News: canon ball
# Predicted: Real, Actual: Real
#
# News: earl sweatshirt doris
# Predicted: Real, Actual: Real
#
# News: my cosplay with over leds nightborne heritage armor from wow
# Predicted: Real, Actual: Fake
#
# News: this one
# Predicted: Real, Actual: Real
#
# News: this announcer has officially seen it all
# Predicted: Real, Actual: Real
#
# News: joke all you have had one maybe two oil services in its life and the turbo shaft end play seems excessive
# Predicted: Real, Actual: Real
#
# News: happy young sloth dangling from a branch
# Predicted: Fake, Actual: Fake
#
# News: does he like olympics
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: taco hell
# Predicted: Real, Actual: Real
#
# News: a smiling dog
# Predicted: Fake, Actual: Fake
#
# News: real anchor arms
# Predicted: Real, Actual: Real
#
# News: katie bouman the moment when the first black hole image was processed
# Predicted: Real, Actual: Real
#
# News: this jacked kangaroo
# Predicted: Real, Actual: Fake
#
# News: merkel
# Predicted: Real, Actual: Real
#
# News: httpsiimgurcomijfepfjpg
# Predicted: Real, Actual: Real
#
# News: hermann goring head of the german luftwaffe goes from elation at the german bombings of warsaw rotterdam and belgrade to horror at the british bombings of lubeck rostock and cologne in this raf leaflet
# Predicted: Fake, Actual: Real
#
# News: become one with the tree
# Predicted: Real, Actual: Real
#
# News: some tiny insect made its way into this bar and left nothing but the almond skins and rice flour puffs bottom bar for reference
# Predicted: Fake, Actual: Fake
#
# News: jumping for freedom
# Predicted: Real, Actual: Fake
#
# News: this parking garage has floors named after celestial bodies still didnt get to park my car in uranus though
# Predicted: Fake, Actual: Fake
#
# News: very fine
# Predicted: Real, Actual: Real
#
# News: thanks
# Predicted: Real, Actual: Real
#
# News: after a heavy rain i found out my eastern red cedars are infected with koosh balls
# Predicted: Fake, Actual: Fake
#
# News: rebels special forces
# Predicted: Real, Actual: Real
#
# News: this cat bathed in light from a stained glass window
# Predicted: Fake, Actual: Fake
#
# News: laughing camels
# Predicted: Real, Actual: Fake
#
# News: michael bays don quixote
# Predicted: Real, Actual: Real
#
# News: i saw the best minds of my generation destroyed by madness
# Predicted: Real, Actual: Real
#
# News: onlinesex
# Predicted: Real, Actual: Real
#
# News: weird peasants who have really accepted this whole work grueling hours every day until you die thing
# Predicted: Real, Actual: Real
#
# News: surprised spoon
# Predicted: Real, Actual: Real
#
# News: i cant remember what i changed
# Predicted: Real, Actual: Real
#
# News: between takes on the set of hg catching fire
# Predicted: Real, Actual: Fake
#
# News: disappointed sinusoidians
# Predicted: Real, Actual: Real
#
# News: this nice owl with a funny expression
# Predicted: Fake, Actual: Fake
#
# News: im so original
# Predicted: Real, Actual: Real
#
# News: adolf hitler giving nazi salute in japan
# Predicted: Fake, Actual: Real
#
# News: poor mans eggs benedict what ive even for breakfast as a leftover casserole after thanksgiving and the sorbet would melt into the pot too hard and they look like shit
# Predicted: Real, Actual: Real
#
# News: head
# Predicted: Real, Actual: Real
#
# News: impossibru
# Predicted: Real, Actual: Real
#
# News: the true residents of easter island
# Predicted: Real, Actual: Real
#
# News: happy box wants a hug
# Predicted: Real, Actual: Real
#
# News: new flaming lips album out soon sexy album art
# Predicted: Real, Actual: Real
#
# News: two illegal aliens being hauled off just days before the wall is completed
# Predicted: Fake, Actual: Real
#
# News: stay put
# Predicted: Real, Actual: Real
#
# News: this puzzle has an extra piece thats almost exactly identical to another but one fits slightly better
# Predicted: Fake, Actual: Fake
#
# News: hannibal barcas crossing of the alps during second punic war ca bc
# Predicted: Real, Actual: Real
#
# News: angry grape
# Predicted: Real, Actual: Real
#
# News: violence is introduced to humanity
# Predicted: Real, Actual: Real
#
# News: vd is not victory us wwii
# Predicted: Real, Actual: Real
#
# News: desktop bowling how shocking
# Predicted: Real, Actual: Real
#
# News: pope i was once a bar bouncer
# Predicted: Real, Actual: Fake
#
# News: this pillow tag that got melted by the vent you can still read it letters are very small
# Predicted: Fake, Actual: Fake
#
# News: getting in on the action
# Predicted: Real, Actual: Real
#
# News: chinese panamanian avalon
# Predicted: Real, Actual: Real
#
# News: my sons trampoline looks like it got kicked in the nuts
# Predicted: Fake, Actual: Real
#
# News: mower died leaving this uncut area of grass looking like a highres minecraft block
# Predicted: Fake, Actual: Fake
#
# News: there thats better
# Predicted: Real, Actual: Real
#
# News: the way car tires have rubbed the pattern off this storm drain lid
# Predicted: Fake, Actual: Fake
#
# News: the search nf
# Predicted: Real, Actual: Real
#
# News: rand paul looks like hes attempting his best dana carvey church lady impersonation
# Predicted: Real, Actual: Fake
#
# News: cat having a stretch
# Predicted: Real, Actual: Fake
#
# News: a refracted smiley face showed up in my water at dinner
# Predicted: Fake, Actual: Real
#
# News: a free tiny library
# Predicted: Real, Actual: Fake
#
# News: the way the sun has warped these sandals
# Predicted: Real, Actual: Fake
#
# News: dog staring at a ball with a crazy look in his eyes
# Predicted: Fake, Actual: Fake
#
# News: americas two year battle from terrorist target to freedoms superpower american magazine from to commemorate the end of the iraq and afghanistan wars pages
# Predicted: Real, Actual: Real
#
# News: happened to see it in a lowes store not sure whether this bird is willing to sell these plants
# Predicted: Fake, Actual: Fake
#
# News: the mirror man
# Predicted: Real, Actual: Fake
#
# News: this tiny petrol station in the middle of paris
# Predicted: Fake, Actual: Fake
#
# News: leaked picture from the inside of notre dame shortly before it went up in flames
# Predicted: Fake, Actual: Real
#
# News: murder kit bros before crows
# Predicted: Real, Actual: Real
#
# News: ant man post end game
# Predicted: Real, Actual: Real
#
# News: tequila cat
# Predicted: Real, Actual: Fake
#
# News: monument valley spire
# Predicted: Real, Actual: Real
#
# News: hold my red bull
# Predicted: Fake, Actual: Real
#
# News: new technique
# Predicted: Real, Actual: Real
#
# News: i wish i was half this happy about anything
# Predicted: Real, Actual: Real
#
# News: patrick its a cyclops ruuuun
# Predicted: Real, Actual: Real
#
# News: meth for fun
# Predicted: Real, Actual: Real
#
# News: chipz from rperfecttiming
# Predicted: Real, Actual: Fake
#
# News: any major lazer fans
# Predicted: Real, Actual: Real
#
# News: tools of the trade
# Predicted: Real, Actual: Real
#
# News: addidas man
# Predicted: Real, Actual: Fake
#
# News: poster for la fiesta del pce an annual communist party of spain celebration in
# Predicted: Fake, Actual: Real
#
# News: so it goes by pentax
# Predicted: Real, Actual: Real
#
# News: crater lake or
# Predicted: Real, Actual: Fake
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: upright dog
# Predicted: Real, Actual: Fake
#
# News: drug tag team clobbers antibioticresistant bacteria
# Predicted: Real, Actual: Fake
#
# News: are you alive neutron death is invisible ussr antiwar poster from ss
# Predicted: Real, Actual: Real
#
# News: pakistani during the indopakistani warbangladeshi liberation war of
# Predicted: Real, Actual: Real
#
# News: sarah palin if youre in america speak american
# Predicted: Real, Actual: Fake
#
# News: i dont even
# Predicted: Real, Actual: Real
#
# News: butt
# Predicted: Real, Actual: Real
#
# News: chesapeake church sign links equal rights to satan
# Predicted: Fake, Actual: Fake
#
# News: general krum
# Predicted: Real, Actual: Real
#
# News: bbc news missing cocker spaniel rescued from m deep dry well
# Predicted: Fake, Actual: Fake
#
# News: surprise cpo on a sled thst was buried with an year old viking ship viking ship museum oslo
# Predicted: Fake, Actual: Fake
#
# News: background image source
# Predicted: Real, Actual: Real
#
# News: mine eyes oo
# Predicted: Real, Actual: Real
#
# News: cat folding its arms
# Predicted: Fake, Actual: Fake
#
# News: les chats sur la maison
# Predicted: Real, Actual: Real
#
# News: he knows how to calm putin down
# Predicted: Real, Actual: Real
#
# News: available here
# Predicted: Real, Actual: Real
#
# News: til berkeley almost banned sitting on the floor til the expression blow smoke out your ass
# Predicted: Real, Actual: Real
#
# News: american soldier meets kangaroo world war
# Predicted: Real, Actual: Fake
#
# News: more like this
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: barbara bush waiving
# Predicted: Real, Actual: Fake
#
# News: i know ooo ooo i know it pick me pick me
# Predicted: Real, Actual: Real
#
# News: early s buddy comedy movie
# Predicted: Real, Actual: Real
#
# News: theres so many
# Predicted: Real, Actual: Real
#
# News: waka waka pacman
# Predicted: Real, Actual: Real
#
# News: arsene wenger out
# Predicted: Real, Actual: Real
#
# News: i made a terrarium in a jar over two years ago and its managed to stay alive the picture on the left is from january and the right is from
# Predicted: Fake, Actual: Fake
#
# News: found this perfectly preserved order form in an old rod stewart album think its too late to order
# Predicted: Real, Actual: Fake
#
# News: netflix socks will pause your show when you doze off
# Predicted: Fake, Actual: Fake
#
# News: man on his mobile suitcase
# Predicted: Fake, Actual: Real
#
# News: this painting of a forest which is actually an eyeball and ya veins
# Predicted: Fake, Actual: Real
#
# News: stichometry my father was a carpenter
# Predicted: Real, Actual: Real
#
# News: michigan state inaccurately spells accurate on lockerroom sign
# Predicted: Fake, Actual: Fake
#
# News: my son went full scorpion on the wall when not in a mirror world
# Predicted: Real, Actual: Real
#
# News: mike tyson on his rather large throne
# Predicted: Fake, Actual: Fake
#
# News: pathway of hope
# Predicted: Real, Actual: Fake
#
# News: not antifascist hungarian peoples republic poster
# Predicted: Real, Actual: Real
#
# News: my taxi driver had a sword as his mode shifting thingidk what its called
# Predicted: Fake, Actual: Fake
#
# News: islamic state sorry for releasing steven sotloff beheading video early
# Predicted: Fake, Actual: Fake
#
# News: scalies are created
# Predicted: Real, Actual: Real
#
# News: corporateinfo leaks
# Predicted: Real, Actual: Real
#
# News: no one murdered because of this image
# Predicted: Real, Actual: Real
#
# News: panda express founders donate million to caltechs medical engineering department
# Predicted: Fake, Actual: Fake
#
# News: this is an oil painting not a photo credit to artist jack hickey irish national gallery
# Predicted: Fake, Actual: Fake
#
# News: kinda nsfw
# Predicted: Real, Actual: Real
#
# News: nick fury finally lost it
# Predicted: Real, Actual: Real
#
# News: mod on a unicycle likes to live dangerously
# Predicted: Real, Actual: Real
#
# News: new york widow in million estate battle gave up another child from china
# Predicted: Fake, Actual: Fake
#
# News: which orchid mantis
# Predicted: Real, Actual: Real
#
# News: this clementine looks like a butt
# Predicted: Fake, Actual: Fake
#
# News: everything is a copy
# Predicted: Real, Actual: Real
#
# News: in theaters nd
# Predicted: Real, Actual: Real
#
# News: he found a purse with credit cards plane tickets then he saw a crying woman
# Predicted: Fake, Actual: Fake
#
# News: woman with horns texting in a bar
# Predicted: Fake, Actual: Real
#
# News: this shadow was the first thing i saw when i woke up today
# Predicted: Fake, Actual: Fake
#
# News: your lungs after smoking one joint be smart
# Predicted: Real, Actual: Real
#
# News: one is not amused
# Predicted: Real, Actual: Real
#
# News: the actor who plays pennywise is gorgeous in real life
# Predicted: Real, Actual: Real
#
# News: this potted pant
# Predicted: Fake, Actual: Fake
#
# News: img
# Predicted: Real, Actual: Real
#
# News: submarino brontosaur and a monkey
# Predicted: Fake, Actual: Real
#
# News: my mix tape was too good not to use a selfie lettermanshortmartin in san diego
# Predicted: Fake, Actual: Real
#
# News: war war never changes
# Predicted: Real, Actual: Real
#
# News: kim deranged trump will pay for speech
# Predicted: Real, Actual: Fake
#
# News: roble roble
# Predicted: Real, Actual: Real
#
# News: british antiataturk
# Predicted: Real, Actual: Real
#
# News: rollercoaster
# Predicted: Real, Actual: Real
#
# News: theres a magnifier to help people read what medicine theyre buying
# Predicted: Fake, Actual: Fake
#
# News: new york subway system cracks down on manspreading
# Predicted: Fake, Actual: Fake
#
# News: frisky
# Predicted: Real, Actual: Real
#
# News: sea cow
# Predicted: Real, Actual: Real
#
# News: independence day of bosniaherzegovina marks the start of the civil war in memoriam nikola gardovic the first victim of the bosnian war a bosnian serb killed during a wedding procession in downtown sarajevo prosrpska
# Predicted: Fake, Actual: Real
#
# News: weeks later
# Predicted: Real, Actual: Real
#
# News: and when you gaze long into an abyss the abyss also gazes into you
# Predicted: Real, Actual: Real
#
# News: ill never let go
# Predicted: Real, Actual: Real
#
# News: snowy river bridge
# Predicted: Real, Actual: Real
#
# News: cruisin with hagrid
# Predicted: Real, Actual: Real
#
# News: its not just a game to me
# Predicted: Real, Actual: Real
#
# News: once this place was a living hell
# Predicted: Real, Actual: Real
#
# News: a big gulp from eleven and a large drink from taco bell are the same cup
# Predicted: Fake, Actual: Fake
#
# News: these spinoffs are starting to get a little ridiculous
# Predicted: Real, Actual: Real
#
# News: arrested for quoting winston churchill european election candidate accused of religious and racial harassment after he repeats wartime prime ministers words on islam during campaign speech
# Predicted: Fake, Actual: Fake
#
# News: found this at the base of a waterfall today
# Predicted: Fake, Actual: Real
#
# News: zwingli and the radicals the secular age
# Predicted: Real, Actual: Real
#
# News: police respond to domestic violence call discover opera singer
# Predicted: Fake, Actual: Fake
#
# News: delicious chocolate cake
# Predicted: Real, Actual: Real
#
# News: hmmm reminds me of someone
# Predicted: Real, Actual: Real
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: ups delivers the first architectural model for the tower of pisa
# Predicted: Fake, Actual: Real
#
# News: tired child falling asleep in tub
# Predicted: Fake, Actual: Fake
#
# News: linus moving a pc when its raining
# Predicted: Fake, Actual: Fake
#
# News: i cant unsee
# Predicted: Real, Actual: Real
#
# News: nuka them from orbit its the only way to be sure
# Predicted: Real, Actual: Real
#
# News: this anthill has a garbage dump of dead ants and insect parts
# Predicted: Fake, Actual: Fake
#
# News: a pair of nice tanned legs at the park
# Predicted: Fake, Actual: Real
#
# News: relationship experts recommend telling woman you would die for her at outset of first date
# Predicted: Fake, Actual: Real
#
# News: vladimir putin calls edward snowden a strange guy
# Predicted: Real, Actual: Fake
#
# News: chicken breast in the forest
# Predicted: Real, Actual: Real
#
# News: spiderman statue removed from south korean playground because it has a gigantic boner
# Predicted: Fake, Actual: Fake
#
# News: if youve got a minute id like to tell you about some great news
# Predicted: Real, Actual: Real
#
# News: was playing smash bros with a friend and after one game i got rd place with kos and falls
# Predicted: Real, Actual: Fake
#
# News: nfl teams want to know if manti teo is gay
# Predicted: Fake, Actual: Fake
#
# News: immortal fans campaign by brazillian football club to encourage more organ donors led to massive increase in lifesaving transplants
# Predicted: Fake, Actual: Fake
#
# News: a tiny dog surfing on the back of a yorkie
# Predicted: Fake, Actual: Real
#
# News: cant believe nobody did this one
# Predicted: Real, Actual: Real
#
# News: this really long cheeto pen and normal sized cheeto for scale
# Predicted: Fake, Actual: Fake
#
# News: the hotel im staying at left a reassuring note under our bed
# Predicted: Fake, Actual: Fake
#
# News: two bands contrasting each other on release day
# Predicted: Fake, Actual: Fake
#
# News: a whole new world
# Predicted: Real, Actual: Real
#
# News: gum in japan comes with little post it notes so you always have paper to spit your gum into
# Predicted: Fake, Actual: Fake
#
# News: construction of the first jaeger from the jaeger program ready to roll out to fight the increasing threat of the kaiju
# Predicted: Fake, Actual: Real
#
# News: hidden mission in spiderman
# Predicted: Real, Actual: Real
#
# News: this blancbleu belge cow
# Predicted: Real, Actual: Fake
#
# News: post called no photoshop hes practically inviting you
# Predicted: Real, Actual: Fake
#
# News: prototype super nintendo
# Predicted: Real, Actual: Real
#
# News: abraham lincoln addresses the negro constituency after signing the bill that abolished slavery
# Predicted: Real, Actual: Real
#
# News: i got an extra large package in this fruit snack box
# Predicted: Fake, Actual: Fake
#
# News: bonjour
# Predicted: Real, Actual: Real
#
# News: irresponsible son filming his dad
# Predicted: Real, Actual: Real
#
# News: realism
# Predicted: Real, Actual: Real
#
# News: small building
# Predicted: Real, Actual: Real
#
# News: coming online this fall
# Predicted: Real, Actual: Real
#
# News: happy new year votes for women
# Predicted: Real, Actual: Real
#
# News: can we fix it
# Predicted: Real, Actual: Real
#
# News: two squirrels playing in the snow captured by a russian photographer
# Predicted: Fake, Actual: Fake
#
# News: this pepper shaker and how it blends in with the table
# Predicted: Fake, Actual: Fake
#
# News: louis ck explains why hillary clinton is the most qualified candidate in one simple analogy
# Predicted: Real, Actual: Real
#
# News: police raid nikolas cruzs bedroom c
# Predicted: Real, Actual: Real
#
# News: questionnaire administered to schoolchildren during the spanish inquisition
# Predicted: Real, Actual: Real
#
# News: lend your five shillings to your country and uk
# Predicted: Real, Actual: Real
#
# News: beached starfish struggles to get back to water
# Predicted: Fake, Actual: Real
#
# News: minor league leftfielder ricky hendersquirrel
# Predicted: Real, Actual: Real
#
# News: quiz has it been an honor to serve with me
# Predicted: Real, Actual: Real
#
# News: now in theaters
# Predicted: Real, Actual: Real
#
# News: ive insulted my best friends more than ive insulted my best friends more than just complain on the internet
# Predicted: Real, Actual: Real
#
# News: post malone and his manager scouting locations to shoot white iverson video circa
# Predicted: Real, Actual: Real
#
# News: last samurai protecting the temple of rokan from american soldiers during world war ca
# Predicted: Real, Actual: Real
#
# News: with ingestible pill you can track fart development in real time on your phone
# Predicted: Fake, Actual: Fake
#
# News: crisis in venezuela too much crime not enough toilet paper
# Predicted: Fake, Actual: Fake
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: this door that leads to a drop
# Predicted: Fake, Actual: Fake
#
# News: things men instantly think of after seeing a busty girl
# Predicted: Real, Actual: Real
#
# News: oleanders new faith
# Predicted: Real, Actual: Real
#
# News: disillusioned and selfdeluded bowe bergdahl vanished into a brutal captivity
# Predicted: Real, Actual: Fake
#
# News: gareth bale celebrating wales qualification to uefa euro
# Predicted: Real, Actual: Fake
#
# News: lil peep instruments of pain
# Predicted: Real, Actual: Real
#
# News: nucky
# Predicted: Real, Actual: Real
#
# News: native americans call for ban on christians entering the us
# Predicted: Fake, Actual: Real
#
# News: a modern look to it
# Predicted: Real, Actual: Real
#
# News: beauty and the beast
# Predicted: Real, Actual: Real
#
# News: stung by popes remarks on armenian genocide turkish minister insults argentina
# Predicted: Fake, Actual: Fake
#
# News: first shop i tried
# Predicted: Real, Actual: Real
#
# News: my sons first catch its a whopper
# Predicted: Real, Actual: Fake
#
# News: everyone is terrified of these fireworks
# Predicted: Real, Actual: Fake
#
# News: this bark in my tree looks like a bird head
# Predicted: Fake, Actual: Real
#
# News: posing backstage at the grammys
# Predicted: Real, Actual: Real
#
# News: this backpacks jimmies remain unrustled
# Predicted: Fake, Actual: Real
#
# News: this house has a vending machine on the front porch for people passing by
# Predicted: Fake, Actual: Fake
#
# News: uc berkeley lecture it is necessary to apply transgender studies to agriculture
# Predicted: Fake, Actual: Fake
#
# News: hes got a plan for the
# Predicted: Real, Actual: Real
#
# News: street cannabis contains large amount of faeces
# Predicted: Fake, Actual: Fake
#
# News: awkward jeb bush just showed up to richard bransons private island in his swim trunks and asked if he could hang out with him like barack obama did
# Predicted: Real, Actual: Real
#
# News: i removed the kid
# Predicted: Real, Actual: Real
#
# News: l found in a balinese temple
# Predicted: Fake, Actual: Real
#
# News: a man in bondage
# Predicted: Real, Actual: Real
#
# News: elton johns protege
# Predicted: Real, Actual: Real
#
# News: itsa pizza pitt
# Predicted: Real, Actual: Real
#
# News: eagle having a very bad hair day
# Predicted: Real, Actual: Real
#
# News: leo inception cat
# Predicted: Real, Actual: Fake
#
# News: for my cake day here is some candy i just bought in taiwan that was made in west germany
# Predicted: Fake, Actual: Fake
#
# News: im flying jack
# Predicted: Real, Actual: Real
#
# News: spain has arrived barcelona francoist spain
# Predicted: Real, Actual: Real
#
# News: harmacy abolish emotion
# Predicted: Real, Actual: Real
#
# News: i am duncan
# Predicted: Real, Actual: Real
#
# News: lizard on a windshield
# Predicted: Fake, Actual: Fake
#
# News: two different colored lights in my room produce this d like color effect for anything casting a shadow
# Predicted: Fake, Actual: Fake
#
# News: the death star wasnt very successful during its early stages
# Predicted: Real, Actual: Real
#
# News: japanese people know the struggle
# Predicted: Real, Actual: Real
#
# News: midair collision between dogs
# Predicted: Fake, Actual: Fake
#
# News: found this fella on my third story window tonight sorry for the glare
# Predicted: Fake, Actual: Fake
#
# News: condescending cat
# Predicted: Real, Actual: Real
#
# News: beary nice to see you
# Predicted: Real, Actual: Real
#
# News: this pen has a stylus level and ruler all in one
# Predicted: Fake, Actual: Fake
#
# News: they way this drop looks like an explosion when hitting a thin layer of water on cement in our dock
# Predicted: Fake, Actual: Fake
#
# News: a face on road
# Predicted: Real, Actual: Real
#
# News: two right arms
# Predicted: Real, Actual: Real
#
# News: ice fall of antarctica
# Predicted: Real, Actual: Fake
#
# News: readers digest at least credits reddit and the redditors for what they use
# Predicted: Fake, Actual: Fake
#
# News: interesting stylized drawing of kylo ren
# Predicted: Fake, Actual: Real
#
# News: taylor swift breaking taylor swift rules
# Predicted: Real, Actual: Real
#
# News: how the white house is shredding its own rules against lobbyists
# Predicted: Real, Actual: Fake
#
# News: what a ice storm does to a pergola
# Predicted: Real, Actual: Fake
#
# News: victorian woman offered compensation after being run over by her pet dog
# Predicted: Fake, Actual: Fake
#
# News: celebrity equinox cruise ship with guests on board reroutes their day cruise itinerary to provide aid for hurricane victims ship chefs created meals while cruise guests packaged and served them
# Predicted: Fake, Actual: Fake
#
# News: worlds beneath worlds
# Predicted: Real, Actual: Fake
#
# News: utahns would vote for trump over clinton despite disliking him more poll shows
# Predicted: Fake, Actual: Fake
#
# News: waterfilled train tracks
# Predicted: Fake, Actual: Fake
#
# News: license plate with rusty bolts looks like it is upside down
# Predicted: Fake, Actual: Real
#
# News: s picture of a guy on a skateboard in central park
# Predicted: Fake, Actual: Fake
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: the beginning of the robotic uprising circa
# Predicted: Real, Actual: Real
#
# News: not so irritated owl
# Predicted: Real, Actual: Real
#
# News: patriots rejoice donald trump has appointed professor rat as the us secretary of fireworks
# Predicted: Real, Actual: Real
#
# News: monster manual iv for use in my obituary
# Predicted: Real, Actual: Real
#
# News: western movie with gov otter have been edited to include sex scenes
# Predicted: Fake, Actual: Fake
#
# News: jagshemash
# Predicted: Real, Actual: Real
#
# News: this cheese grater is extra happy today
# Predicted: Fake, Actual: Real
#
# News: madam of world destruction
# Predicted: Real, Actual: Real
#
# News: he wants to party too
# Predicted: Real, Actual: Real
#
# News: happy eyed audio
# Predicted: Real, Actual: Real
#
# News: coming this fall
# Predicted: Real, Actual: Real
#
# News: seems about right
# Predicted: Real, Actual: Fake
#
# News: the fly
# Predicted: Real, Actual: Real
#
# News: de sade leanne
# Predicted: Real, Actual: Real
#
# News: rick and morty watching tv
# Predicted: Real, Actual: Fake
#
# News: here you go
# Predicted: Real, Actual: Real
#
# News: cannibals devour helpless man while brother watches in horror
# Predicted: Fake, Actual: Real
#
# News: the footage has since been lost circa
# Predicted: Real, Actual: Real
#
# News: first thing i thought of
# Predicted: Real, Actual: Real
#
# News: leicestershire police ignore attempted burglaries at oddnumbered houses
# Predicted: Fake, Actual: Fake
#
# News: sikh school children raise k for muslim girl who lost her entire family in a house fire
# Predicted: Fake, Actual: Fake
#
# News: i work in a warehouse and every box we receive is assigned a random digit number this one got top right
# Predicted: Fake, Actual: Fake
#
# News: this dog with an underbite
# Predicted: Fake, Actual: Fake
#
# News: childrens hospital turns bedtime into playtime by replacing white sheets with interactive game sheets
# Predicted: Fake, Actual: Fake
#
# News: instead of a peephole this door has another smaller door cut in it
# Predicted: Fake, Actual: Fake
#
# News: in the name of the moon i will punish you
# Predicted: Real, Actual: Real
#
# News: yearold australian man was trapped under his car for four days before help arrived throughout the ordeal his loyal dog boydy never left his side
# Predicted: Fake, Actual: Fake
#
# News: the tiles match up perfectly minutes after hometime
# Predicted: Fake, Actual: Fake
#
# News: noticed this cute face on my wall after living here for months
# Predicted: Fake, Actual: Fake
#
# News: men fired in wake of metoo come forward about how it took them several hours to find new jobs
# Predicted: Fake, Actual: Real
#
# News: cutout
# Predicted: Real, Actual: Real
#
# News: froze my drink and the text and symbol in the cap perfectly show on the ice
# Predicted: Fake, Actual: Fake
#
# News: traffic light long exposure
# Predicted: Real, Actual: Fake
#
# News: spiral stairs
# Predicted: Real, Actual: Real
#
# News: geography of canada truth is the first casualty ethereal post jazz
# Predicted: Real, Actual: Real
#
# News: second exhibition theme puss in boots
# Predicted: Real, Actual: Real
#
# News: xenobrown
# Predicted: Real, Actual: Real
#
# News: photo bomber in times square
# Predicted: Fake, Actual: Fake
#
# ...
# Predicted: Real, Actual: Real
#
# News: philippines police describe kill rewards staged crime scenes in dutertes drug war
# Predicted: Fake, Actual: Fake
#
# News: this rod is making an impression in the concrete every time its dropped
# Predicted: Fake, Actual: Fake
#
# News: update my thicc kinder surprise egg was actually two eggs
# Predicted: Fake, Actual: Fake
#
# News: the way the wrapping on the individual sticks of gum lines up
# Predicted: Fake, Actual: Fake
#
# News: dragon cloud its even got faint horns
# Predicted: Real, Actual: Fake
#
# News: a second look is not enough
# Predicted: Real, Actual: Real
#
# News: httpsimgurcomrpnvqjpg
# Predicted: Real, Actual: Real
#
# News: snake man
# Predicted: Real, Actual: Real
#
# News: putin personally hacks the usa election
# Predicted: Fake, Actual: Real
#
# News: the way the drips from the ac vent hit this painting
# Predicted: Fake, Actual: Fake
#
# News: wheeeeeeee
# Predicted: Real, Actual: Real
#
# News: the bark of this tree looks like someone is standing inside
# Predicted: Fake, Actual: Fake
#
# News: antichild marriage united nations
# Predicted: Real, Actual: Real
#
# News: turkish sociologist fehmi kaya apologises for suggesting link between atheism and autism
# Predicted: Fake, Actual: Fake
#
# News: dinklage for scale
# Predicted: Real, Actual: Real
#
# News: third grader picks best research in cognitive neuroscience
# Predicted: Fake, Actual: Fake
#
# News: the day b learned to love b
# Predicted: Real, Actual: Real
#
# News: what do you say we fill this picture with bunch of stuff
# Predicted: Real, Actual: Real
#
# News: and now win the peace uk
# Predicted: Real, Actual: Real
#
# News: ah dammit
# Predicted: Real, Actual: Real
#
# News: i need your helptake time off uk ww
# Predicted: Real, Actual: Real
#
# News: such grace
# Predicted: Real, Actual: Real
#
# News: this is what america and the national anthem by high school homecoming game
# Predicted: Real, Actual: Real
#
# News: justin trudeau gets ready for a costume party with help from his friends
# Predicted: Fake, Actual: Real
#
# News: my happy coffee
# Predicted: Real, Actual: Real
#
# News: just a dream
# Predicted: Real, Actual: Real
#
# News: the way my screen protector cracked and made a mountain range
# Predicted: Fake, Actual: Fake
#
# News: i also have a friend that buys paintings from the thrift store but adds robots and monkeys to make them cooler than all these others ones
# Predicted: Fake, Actual: Fake
#
# News: this starbucks cup is yuge
# Predicted: Fake, Actual: Real
#
# News: httpsiimgurcomchluyljpg
# Predicted: Real, Actual: Real
#
# News: i just minimized a video in the youtube app and saw this
# Predicted: Fake, Actual: Real
#
# News: this building thst looka really weird from one angle
# Predicted: Real, Actual: Real
#
# News: available here
# Predicted: Real, Actual: Real
#
# News: this tree shortly after it was hit by lightning
# Predicted: Fake, Actual: Fake
#
# News: there is water sprayed into the air so people who walk by can cool off
# Predicted: Fake, Actual: Fake
#
# News: the real hero
# Predicted: Real, Actual: Real
#
# News: busy man has spoonful of cereal on trip from kitchen to couch
# Predicted: Fake, Actual: Real
#
# News: a picture of my son going down a slide
# Predicted: Fake, Actual: Fake
#
# News: young mom cries out in pain weeks after her boyfriend surprises her with this new designer bag
# Predicted: Fake, Actual: Real
#
# News: oops
# Predicted: Real, Actual: Real
#
# News: driver of suv that hit cyclists suing dead teens family
# Predicted: Fake, Actual: Fake
#
# News: marine dad surprises son by celebrating holidays early before deployment
# Predicted: Fake, Actual: Fake
#
# News: look that rabbits got a vicious streak a mile wide its a killer
# Predicted: Real, Actual: Real
#
# News: the way you can see my laptop screens polarizing filter with my polarized sunglasses
# Predicted: Fake, Actual: Fake
#
# News: i think i found a microwave popcorn on the walkie talkie or from the sea
# Predicted: Fake, Actual: Real
#
# News: local hero who cleaned up vandals mess shocked at reception good deed has received
# Predicted: Fake, Actual: Fake
#
# News: swift current lake it is not treason to want freedom
# Predicted: Real, Actual: Real
#
# News: the wright brothers first flight
# Predicted: Real, Actual: Real
#
# News: summer ride with my buddies in our new convertible
# Predicted: Fake, Actual: Real
#
# News: new footage of the japanese tsunami
# Predicted: Real, Actual: Real
#
# News: borobudur
# Predicted: Real, Actual: Fake
#
# News: a cross section of daft punk
# Predicted: Real, Actual: Real
#
# News: face spotted on pchuryumovgerasimenko x
# Predicted: Real, Actual: Real
#
# News: this frozen egg
# Predicted: Fake, Actual: Fake
#
# News: kingbug
# Predicted: Real, Actual: Real
#
# News: the tiananmen square massacre
# Predicted: Real, Actual: Real
#
# News: chicago night
# Predicted: Real, Actual: Fake
#
# News: super patricia
# Predicted: Real, Actual: Real
#
# News: creative burj khalifa image
# Predicted: Real, Actual: Fake
#
# News: mother to receive kidney transplant after money raised in was stolen
# Predicted: Fake, Actual: Fake
#
# News: left my water cup in the freezer for too long and it split perfectly
# Predicted: Fake, Actual: Fake
#
# News: this loaf of bread that was accidentally cut lengthwise
# Predicted: Fake, Actual: Fake
#
# News: no explanation
# Predicted: Real, Actual: Real
#
# News: sean cooper pays off mortgage in years and earns online hate
# Predicted: Fake, Actual: Fake
#
# News: my dad burnt these in our family buffet and we couldnt sell them than i wrote say no to racism on them and we sold it all plus everyone had a good laugh about it
# Predicted: Real, Actual: Fake
#
# News: the british two pound coin has detailed engravings of the dna nucleic acid sequence
# Predicted: Fake, Actual: Fake
#
# News: the way the tortilla has the same exact shape as the egg above it so that you can hardly see it
# Predicted: Fake, Actual: Fake
#
# News: the inside of the pizza box was a tuxedo
# Predicted: Fake, Actual: Fake
#
# News: father guido sarducci
# Predicted: Real, Actual: Real
#
# News: no those are my nuts emma
# Predicted: Real, Actual: Real
#
# News: httpsiimgurcomtratysjpg
# Predicted: Real, Actual: Real
#
# News: clothes monster
# Predicted: Real, Actual: Real
#
# News: forever urban agriculture
# Predicted: Real, Actual: Real
#
# News: nocrowd stage dive
# Predicted: Real, Actual: Real
#
# News: the beehive collective posters us modern
# Predicted: Real, Actual: Real
#
# News: jack the giant slayer
# Predicted: Real, Actual: Real
#
# News: one small step for dog one giant leap for dog kind
# Predicted: Real, Actual: Real
#
# News: yoga flame
# Predicted: Real, Actual: Real
#
# News: video diversity win these men are wearing motioncapture suits so someone who knows how to do special effects can turn them into women of color
# Predicted: Fake, Actual: Real
#
# News: meth is one hell of a drug
# Predicted: Real, Actual: Real
#
# News: feds fight suit over foreign payments to trump
# Predicted: Fake, Actual: Fake
#
# News: the purple colour of this soda faded in the sun
# Predicted: Fake, Actual: Fake
#
# News: the andy griffth show had some happy little trees
# Predicted: Fake, Actual: Fake
#
# News: taking in the view
# Predicted: Real, Actual: Fake
#
# News: boeing cuts max output in wake of two deadly crashes
# Predicted: Fake, Actual: Fake
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: this gummy worm mistake sort of looks like a skeletons hand
# Predicted: Fake, Actual: Fake
#
# News: harvard writer free speech threatens liberalism and must be destroyed
# Predicted: Real, Actual: Fake
#
# News: klitschko receiving a massive uppercut
# Predicted: Real, Actual: Fake
#
# News: ill take the bulbasaur salad
# Predicted: Real, Actual: Real
#
# News: this brick looks like this meme of toad
# Predicted: Fake, Actual: Real
#
# News: this map will change the way you see westeros reports neverending cascade of subhuman bullshit
# Predicted: Real, Actual: Real
#
# News: still hope
# Predicted: Real, Actual: Real
#
# News: hero bus driver reveals putney bridge jogger rugby tackled woman onto the road
# Predicted: Fake, Actual: Real
#
# News: ohio township children of the empire
# Predicted: Real, Actual: Real
#
# News: shhhh only dreams now
# Predicted: Real, Actual: Real
#
# News: campaign poster us election x
# Predicted: Real, Actual: Real
#
# News: frustrated fathers letter to macys ceo spurs new changing table inside store mens room
# Predicted: Fake, Actual: Fake
#
# News: you probably dont want to buy me after all
# Predicted: Real, Actual: Real
#
# News: chinese man lives under bridge for years to crack lottery code
# Predicted: Fake, Actual: Fake
#
# News: wrong body cremated at funeral of tory mep philip bradbourn
# Predicted: Fake, Actual: Fake
#
# News: a bean plant supported by thick bamboo and tied together using thin bamboo all grown in my garden nature supporting each other
# Predicted: Fake, Actual: Fake
#
# News: i think she might be trying to influence him
# Predicted: Real, Actual: Real
#
# News: a new mcdonalds grandopening in russia
# Predicted: Fake, Actual: Fake
#
# News: you dont typically see an ice cream vending machine
# Predicted: Fake, Actual: Fake
#
# News: my ricearoni box had two seasoning packs
# Predicted: Fake, Actual: Fake
#
# News: genghis khan breaching the great wall of china
# Predicted: Real, Actual: Real
#
# News: jade allen cuddles with trubs her yearold rescue from new beginnings for cats allen who has sensory procesing disorder bonded with trubs whose special needs deemed him almost unadoptable during a visit to pet the kitties at the shelter one year ago
# Predicted: Fake, Actual: Fake
#
# News: with a magnifying glass you can make out the sticker and lightbulb stem in my lamp
# Predicted: Fake, Actual: Fake
#
# News: affirmative dissatistaction a lawsuit reveals how peculiar harvards definition of merit is the universitys reputation for fairness and impartiality emerges bruised
# Predicted: Real, Actual: Fake
#
# News: new york legal aid lawyers stage walkout after yet another ice court arrest
# Predicted: Fake, Actual: Fake
#
# News: woman and her sad dog
# Predicted: Fake, Actual: Real
#
# News: these small insects only land on the green toboggans
# Predicted: Fake, Actual: Fake
#
# News: this building in moscow
# Predicted: Fake, Actual: Fake
#
# News: dads holding drinks for their kids
# Predicted: Fake, Actual: Fake
#
# News: available here
# Predicted: Real, Actual: Real
#
# News: the bug eyes staring into space
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: this strawberry champagne has more grape juice and cherry juice than strawberry
# Predicted: Fake, Actual: Fake
#
# News: theyll never get me up here
# Predicted: Real, Actual: Real
#
# News: subreddits banning people for criticizing ugallowboob
# Predicted: Fake, Actual: Real
#
# News: imgur
# Predicted: Real, Actual: Real
#
# News: donald trump transforming into a super saiyan for the first time
# Predicted: Fake, Actual: Real
#
# News: hei mama kanzhe wo mama mama ai mama kan mama
# Predicted: Real, Actual: Real
#
# News: thought kim k became a dwarf for a moment
# Predicted: Real, Actual: Real
#
# News: themenace
# Predicted: Real, Actual: Real
#
# News: car w est sun bobble heads inside the car
# Predicted: Fake, Actual: Fake
#
# News: i had an extra fruit winder in my fruit winder lol
# Predicted: Fake, Actual: Fake
#
# News: cavalry mobilizing for the great skeleton war
# Predicted: Real, Actual: Real
#
# News: wax on wax off
# Predicted: Real, Actual: Real
#
# News: ascwulf a girl who can really play guitar
# Predicted: Real, Actual: Real
#
# News: i stuck a thumbtack through a bottle of water mid to late and finally took it out
# Predicted: Fake, Actual: Fake
#
# News: crab and cockatiel
# Predicted: Fake, Actual: Fake
#
# News: m powerball jackpot winner take this job and
# Predicted: Real, Actual: Fake
#
# News: for hyrule
# Predicted: Real, Actual: Real
#
# News: news the perils of climate change a rise in sea level of just one foot would be devastating for the man tied to this pier
# Predicted: Real, Actual: Real
#
# News: available here
# Predicted: Real, Actual: Real
#
# News: i squished a mosquito on my hand and it left a perfect outline
# Predicted: Fake, Actual: Fake
#
# News: everybody tango
# Predicted: Real, Actual: Real
#
# News: this coffee cup from krispy kreme
# Predicted: Fake, Actual: Real
#
# News: our treehouse w vines made an old tree stump look like a live tree again
# Predicted: Fake, Actual: Fake
#
# News: australia inplements new anthem
# Predicted: Real, Actual: Real
#
# News: donald trump in primary school
# Predicted: Real, Actual: Real
#
# News: spare me spare me
# Predicted: Real, Actual: Real
#
# News: that made me moist
# Predicted: Real, Actual: Real
#
# News: obama reacting to raul castro
# Predicted: Real, Actual: Fake
#
# News: hillary planning presidential candidate library
# Predicted: Real, Actual: Real
#
# News: a large mountain pass with a guy in the middle
# Predicted: Fake, Actual: Fake
#
# News: these hairs do not approve
# Predicted: Real, Actual: Real
#
# News: robin stood on a metal hand
# Predicted: Fake, Actual: Fake
#
# News: a metro goldwyn meow
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: these flowers finding a way to survive urban life
# Predicted: Fake, Actual: Fake
#
# News: european countries in the lead up to ww
# Predicted: Real, Actual: Real
#
# News: hell of a ride
# Predicted: Real, Actual: Real
#
# News: pole vaulter in mid air from the beijing olympics
# Predicted: Fake, Actual: Fake
#
# News: stranded bride gets police car lift to wedding in bibury
# Predicted: Fake, Actual: Fake
#
# News: the old snowman
# Predicted: Real, Actual: Real
#
# News: this bubble looks like it is a low quality digital sticker
# Predicted: Fake, Actual: Fake
#
# News: new research finds that nonmarital birth is declining in the us more babies are born to cohabiting couples and much much less to teen moms
# Predicted: Fake, Actual: Fake
#
# News: some garage band in recording an angry rebellious song to compete with the beatles and the rolling stones
# Predicted: Real, Actual: Real
#
# News: the inside of a bottle left in the freezer too long
# Predicted: Fake, Actual: Fake
#
# News: good taste
# Predicted: Real, Actual: Real
#
# News: bills targeting chinas huawei introduced in us congress
# Predicted: Fake, Actual: Fake
#
# News: the japanese recruiting kamikaze bombers colored
# Predicted: Real, Actual: Real
#
# News: opened my straw to find it redundant
# Predicted: Real, Actual: Fake
#
# News: squadron entering japanese airspace circa
# Predicted: Real, Actual: Real
#
# News: a man and the mountain
# Predicted: Real, Actual: Real
#
# News: rfakehistoryporn decides to ban memes
# Predicted: Real, Actual: Real
#
# News: adolf hitler meeting neville chamberlain for the first time colourized
# Predicted: Real, Actual: Real
#
# News: scat on baby
# Predicted: Real, Actual: Real
#
# News: thank you beloved stalin for happy childhood ussr
# Predicted: Real, Actual: Real
#
# News: the furry yeti
# Predicted: Real, Actual: Real
#
# News: the myth of american exceptionalism
# Predicted: Real, Actual: Fake
#
# News: d
# Predicted: Real, Actual: Real
#
# News: helicopter crash graphic
# Predicted: Real, Actual: Real
#
# News: the difference between bernie and hillary
# Predicted: Real, Actual: Real
#
# News: too exited ostrich bird
# Predicted: Fake, Actual: Fake
#
# News: a turkey wing made from a slice of turkey wing
# Predicted: Fake, Actual: Fake
#
# News: some early deaths in researching electricity and lightning
# Predicted: Fake, Actual: Fake
#
# News: apocalypse here and now war is heck
# Predicted: Real, Actual: Real
#
# News: illinois senate passes puppy lemon legislation
# Predicted: Fake, Actual: Fake
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: phone calls from new york city jails will soon be free
# Predicted: Fake, Actual: Fake
#
# News: when neckbeards go too far lpt have a nice guy is a palindrome
# Predicted: Real, Actual: Real
#
# News: women prefer men with big bellies
# Predicted: Real, Actual: Fake
#
# News: this happy little keychain
# Predicted: Fake, Actual: Real
#
# News: she took the lead
# Predicted: Real, Actual: Real
#
# News: isle of iona scotland
# Predicted: Real, Actual: Fake
#
# News: juno jupiter descending variants inside
# Predicted: Real, Actual: Real
#
# News: sputnik
# Predicted: Real, Actual: Real
#
# News: cutouts
# Predicted: Real, Actual: Real
#
# News: unusual tap in my hospital room
# Predicted: Fake, Actual: Fake
#
# News: other discussions
# Predicted: Real, Actual: Real
#
# News: windsurfing
# Predicted: Real, Actual: Real
